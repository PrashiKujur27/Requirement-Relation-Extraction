# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import re

# %% [markdown]
# ## Load the Raw Dataset

# %%
df = pd.read_csv("semiLabelledData.csv")

print("🔹 Original shape:", df.shape)
print("🔹 Columns available:", df.columns.tolist())

df.head()
# Out:
# 🔹 Original shape: (10658, 11)
# 🔹 Columns available: ['Unnamed: 0.1', 'Unnamed: 0', 'req1', 'req1_id', 'req2', 'req2_id', 'similarity', 'cosine', 'BinaryClass', 'MultiClass', 'Id']
#    Unnamed: 0.1  Unnamed: 0  \
# 0          9999        9999
# 1          9999        9999
# 2          9999        9999
# 3          9999        9999
# 4          9999        9999
#
#                                                 req1    req1_id  \
# 0  the current operational status shall be indica...  PURE_B001
# 1  isolation of the etcs trainborne equipment sha...  PURE_B002
# 2  the driver shall know the distance to the next...  PURE_B003
# 3  the driver shall know the distance to the next...  PURE_B003
# 4  the dmi shall indicate the result of the self-...  PURE_B004
#
#                                                 req2    req2_id  similarity  \
# 0  the dmi shall indicate the result of the self-...  PURE_B004        9999
# 1  the etcs trainborne equipment shall transmit i...  PURE_B029        9999
# 2  when the traction unit has come to a standstil...  PURE_B068        9999
# 3  the driver shall be able to use the reversing ...  PURE_B055        9999
# 4  operation of the train trip shall be indicated...  PURE_B099        9999
#
#    cosine  BinaryClass  MultiClass    Id
# 0    9999            1        9999  9999
# 1    9999            0        9999  9999
# 2    9999            0        9999  9999
# 3    9999            0        9999  9999
# 4    9999            1        9999  9999

# %% [markdown]
# ## Select Useful Columns

# %%
df = df[["req1", "req2", "BinaryClass"]].copy()

# %% [markdown]
# ## Remove Missing / Invalid Data

# %%
df.dropna(subset=["req1", "req2", "BinaryClass"], inplace=True)
df = df[df["req1"].apply(lambda x: isinstance(x, str))]
df = df[df["req2"].apply(lambda x: isinstance(x, str))]

# %% [markdown]
# ## Clean Text

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r"http\S+", "", text)      # remove URLs
    text = re.sub(r"[^a-z\s]", "", text)     # remove punctuation/numbers
    text = re.sub(r"\s+", " ", text).strip() # remove extra spaces
    return text

df["req1"] = df["req1"].apply(clean_text)
df["req2"] = df["req2"].apply(clean_text)

# %% [markdown]
# ## Remove Duplicates & Invalid Labels

# %%
df = df[(df["req1"].str.len() > 3) & (df["req2"].str.len() > 3)]
df.drop_duplicates(subset=["req1", "req2"], inplace=True)
df.rename(columns={"BinaryClass": "label"}, inplace=True)
df = df[df["label"].isin([0, 1])]

# %% [markdown]
# ## Save Cleaned Dataset

# %%
output_file = "cleaned_requirements.csv"
df.to_csv(output_file, index=False)

print(f"✅ Cleaned dataset saved as '{output_file}'")
print("✅ Total rows after cleaning:", len(df))
df.head()
# Out:
# ✅ Cleaned dataset saved as 'cleaned_requirements.csv'
# ✅ Total rows after cleaning: 10418
#                                                 req1  \
# 0  the current operational status shall be indica...
# 1  isolation of the etcs trainborne equipment sha...
# 2  the driver shall know the distance to the next...
# 3  the driver shall know the distance to the next...
# 4  the dmi shall indicate the result of the selftest
#
#                                                 req2  label
# 0  the dmi shall indicate the result of the selftest      1
# 1  the etcs trainborne equipment shall transmit i...      0
# 2  when the traction unit has come to a standstil...      0
# 3  the driver shall be able to use the reversing ...      0
# 4  operation of the train trip shall be indicated...      1

# %% [markdown]
# ## Install & Import Libraries

# %%
# Install missing package(s) in the notebook environment
# %pip install -q datasets
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -q transformers
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -q torch
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split
from datasets import Dataset
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
import torch
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
